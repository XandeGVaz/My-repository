# %% [markdown]
# # <font color='gren'> Cálculo Numérico - Atividade 1

# %% [markdown]
# ## **Alunos:**
# * Gabriel Dezejácomo Maruschi - 14571525
# * Vitor Alexandre Garcia Vaz - 14611432
# * Vitor Pardini Saconi -14611800

# %% [markdown]
# ## **Funções prévias**

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy
from scipy import sparse

# %%
def GeraRede(n,m,CH,CV):
    nv = n*m
    nc = (n-1)*m + (m-1)*n
    
    coord = np.zeros(shape=(nv,2))

    for i in range(n):
      for j in range(m):
        ig = i + j*n
        coord[ig,0] = i
        coord[ig,1] = j

    conec = np.zeros(shape=(nc,2), dtype=int)
    C = np.zeros(nc)
    
    # Loop sobre canos horizontais
    for j in range(m):
        for i in range(n-1):
          k = j*(n-1) + i
          conec[k,0] = j*n + i
          conec[k,1] = j*n + i+1
          C[k] = CH

    # Loop sobre canos verticais
    for i in range(n):
      for j in range(m-1):
          k = (n-1)*m + j*n + i
          conec[k,0] = i + j*n
          conec[k,1] = i + (j+1)*n
          C[k] = CV

    return nv, nc, conec, C, coord

# %%
def PlotPressure(m, n, pressure):
    x = np.arange(0, m, 1)
    y = np.arange(0, n, 1)
    X,Y=np.meshgrid(x,y)
    Z = np.copy(pressure)
    Z.shape = (n,m)
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_aspect('equal')
    ax.set(xlabel='x', ylabel='y', title='Contours of pressure')
    ax.grid()
    ax.set_xticks(x)
    ax.set_yticks(y)
    cp = plt.contourf(X, Y, Z, cmap='jet')
    cb = plt.colorbar(cp)
    plt.show()

def PlotPressureAsSurface(m, n, pressure):
    x = np.arange(0, m, 1)
    y = np.arange(0, n, 1)
    X,Y=np.meshgrid(x,y)
    Z = np.copy(pressure)
    Z.shape = (n,m)
    fig, ax = plt.subplots(figsize=(10,10))
    ax.set_aspect('equal')
    ax.set(xlabel='x', ylabel='y', title='Contours of pressure')
    ax.grid()
    ax.set_xticks(x)
    ax.set_yticks(y)
    ax = plt.axes(projection="3d")
    ax.plot_surface(X, Y, Z, cmap='jet', edgecolor=None)
    ax.set(xlabel='$x$', ylabel='$y$', zlabel='$z$')
    ax.view_init(elev=30., azim=45)
    plt.show()

# %%
#Exercício 1
def Assembly(conec, C):
    nc = conec.shape[0]
    nv = conec[0,0]
    for i in range(nc):
        for j in range(2):
            if conec[i, j] > nv:
                nv = conec[i,j]
    nv += 1
    A = np.zeros(shape=(nv, nv))

    for j in range(nc):
        A[conec[j, 0], conec[j, 0]] += C[j]
        A[conec[j, 1], conec[j, 1]] += C[j]
        A[conec[j, 0], conec[j, 1]] -= C[j]
        A[conec[j, 1], conec[j, 0]] -= C[j]

    return A

# %%
#Exercício 2
def SolveNetwork(conec, natm, nb, Qb, C):
    Atil = Assembly(conec, C)
    aux = np.zeros(shape=Atil.shape[1])
    aux[natm] = 1
    Atil[natm] = aux
    Atil_aux = scipy.sparse.csr_matrix(Atil)

    b = np.zeros(shape=Atil.shape[0])
    b[nb] = Qb

    

    pressure = sparse.linalg.spsolve(Atil_aux, b)
    return pressure

# %%
#Exercício 3
def CalculaVazoes(C, conec, p, nc, nv):
    #Calculo de K
    K = np.zeros(shape=(nc, nc))
    for i in range(nc):
        K[i, i] = C[i]

    #Calculo de D
    D = np.zeros(shape=(nc, nv))
    for i in range(nc):
        for j in range(nv):
            D[i, conec[i, 0]] = 1
            D[i, conec[i, 1]] = -1

    Q = K@D@p
    return Q

# %% [markdown]
# ## **Cálculo de probabilidade**

# %% [markdown]
# **Pré-setagem necessária**

# %%
#Definições e geração da rede
nx = 10 #Número de nós horizontais
ny = 10 #Número de nós verticais
CH = 2. 
CV = 2.0

natm = nx*ny-1
nb = 0
Qb = 10

pressureMax = 12 #Pressão máxima limite (parâmetro)

nv, nc, conec, C, coord = GeraRede(nx, ny, CH, CV)

#Alteração de C (inclusão dos canos grossos)
lst = [0, 1, 2, 30, 31, 32, 93, 103, 113]
C[lst] = 20.0

count_overflow = 0 # numero de casos em que a pressão foi maior que 12
Centup = 0.2 # Condutividade do cano entupido

# %% [markdown]
# **Referentemente ao cálculo de probaibilidade, o grupo desenvolveu duas funções principais:**
# * A primeira delas é a "RandomFailFinos", a qual - com base em uma probabilidade de entupimento - formará um novo vetor de condutâncis , no qual os canos que entupiram estarão com suas condutãncias alteradas para um valor predefinido (0,2).

# %%
def RandomFailFinos(C, prob0, Centup):
    Cnew = np.copy(C)
    nc = C.shape[0]
    vetor_aux = np.random.rand(nc) # Calcula um número aletório para cada cano

    for i in range(nc):
        if C[i]==2.0:
            if(vetor_aux[i] <= prob0): # Se o número for menor ou igual prob0, o cano entupiu
                Cnew[i] = Centup

    return Cnew

# %% [markdown]
# * Além disso, o grupo também desenvolveu a função "ProbOverPressMax" que, com base em uma pressão limite pré-determinada e em uma probabilidade de entupimento, retorna a probabilidade de a pressão máxima limite da rede ser ultrapassada. Valendo lembrar que tal função já considera a nova lista de condutâncias com os valores alterados para os canos entupidos.
#
#  *Para isso usamos o mesmo princípio do cálculo do número pi, que consiste em dividir o número de testes em que a pressão limite foi excedida pelo número total de testes.*
#
#  *A fim de otimizar a execução do programa, incluimos a biblioteca scipy visando a utilização da matriz exparsa para a resolução do sistema dentro da função "SolveNetwork", escolha a qual possibilitou um processo mais rápido de cálculo das pressões nos nós.*

# %%
def ProbOverPressMax(pressureMax, prob0, nTestes):
    count_overflow = 0
    for i in range(nTestes):
        Cnew = RandomFailFinos(C, prob0, Centup)
        pressure = SolveNetwork(conec, natm, nb, Qb, Cnew)
        pm = np.max(pressure)
        if pm > pressureMax:
            count_overflow += 1
    probFinal = count_overflow/nTestes
    return probFinal

# %% [markdown]
# ## **Definição do conjunto de dados**

# %%
quantMC = 6 # Quantidade de variações para os testes no cálculo de Monte Carlo
MCs = np.linspace(5000, 10000, quantMC) # Numero de testes realizados no cálculo de Monte Carlo
quantProbs = 11 # Quantidade de testes de probabilidade de entupimento
probs = np.linspace(0.0, 0.3, quantProbs)

# Calculo da probabilidade de excedimento da pressão limite
ti = time.time()
probsOver = np.zeros(shape=(quantProbs * quantMC))
for i in range(quantMC):
    for j in range(quantProbs):
        probsOver[i*quantProbs+j] = ProbOverPressMax(pressureMax, probs[j], int(MCs[i]))
tf = time.time()-ti
print("Tempo de execução:", tf)
# Out:
# Tempo de execução: 337.17434191703796

# %% [markdown]
# ## **Plotagem dos resultados**

# %% [markdown]
# **Plot de gráfico**

# %%
# Plot do gráfico

X,Y=np.meshgrid(probs, MCs)
Z = np.copy(probsOver)
Z.shape = (quantMC,quantProbs)
fig, ax = plt.subplots(figsize=(10,10))
ax.set_aspect('equal')
ax.set(title='Gráfico da probabilide de exceder pressão limite em função da pressão e do número de testes estatísticos')
ax.grid()
ax.set_xticks(probs)
ax.set_yticks(MCs)
print(Y.shape)
ax = plt.axes(projection="3d")
ax.plot_surface(X, Y, Z, cmap='jet', edgecolor=None)
ax.set(xlabel='Probabilidade de entupimento', ylabel='N de testes', zlabel='Probabilidade de exceder pressão limite')
ax.view_init(elev=30., azim=135)
plt.show()
# Out:
# (6, 11)

# %% [markdown]
# **Plot de tabela**

# %%
# Plot da tabela
relacao = np.zeros(shape=(quantProbs, 2))
for i in range(quantProbs):
    relacao[i, 0] = round(probs[i], 3)
    relacao[i, 1] = probsOver[i]
colunas = ("Prob. entupimento", "Prob. de superar pressão máxima")
plt.title("Tabela da prob. da pressão máxima exceder 12 em função da prob. de entupimento dos canos finos para 5000 testes")
plt.table(cellText=relacao, colLabels=colunas, loc='center', colLoc='center', cellLoc='center')

# %% [markdown]
# ## **Conclusões**
#
# **Analisando os resultados , foi possível observar um crscimento da probabilidade de excedimento da pressão-limite proporcional à probabilidade de entupimento dos canos finos. Nesse viés, três análises principais - abrangendo esse crescimento - foram concluidas pelo grupo:**
#
# * Em primeiro lugar, levando em conta um número de 5000 testes,  o crescimento da probabilidade de ultrapassagem cresce linearmente - com um fator de proporcionalidade de 2,5 - quando a probabilidade de entupimento dos canos finos varia de 0,0 até 0,15. Tal fato pode ser notado pois, analisando a tabela, entre os valores de probabilidade de entupimento de 0,015 a 0,15 houve um aumento em uma fator de 10 dessa probabilidade, enquanto a probabilidade de ultrapassagem da pressão limite aumentou cerca de 25 vezes ( de 0,0326 até 0,83).
#
# * Em segundo lugar, a partir da probabilidade de entupimento de 0,15 , houve uma diminuição do crescimento da probabilidade de ultrapassagem do limite de pressão, porém, a partir do momento em que a probabilidade de entupimento atinge 0,225, a probabilidade de ultrapassagem é praticamente 1,0 (100%), ou seja, se a probabilidade de entupimento dos canos finos for igual ou maior a 0,225(22,5%), o uso de tal rede torna-se inviável, já que ela apresentará problemas por ter tido seu limite de pressão excediddo.
#
# * Em terceiro lugar, os padrões mencionados anteriormente se repetem para maiores números de testes, conforme é possível notar no gráfico plotado.
